# %%
# !pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=52f2d08868e2004f89672f7c47b8d9df46789f5ffc9c88073f356d2de828c75e
#   Stored in directory: /root/.cache/pip/wheels/77/3d/a6/d317a6fb32be58a602b1e8c6b5d6f31f79322da554cad2a5ea
# Successfully built apyori
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import matplotlib.dates as mdates
# %matplotlib inline
from apyori import apriori

# %%
tv = pd.read_csv("TV Shows - Association Rule Learning.csv")

# %%
tv.shape
# Out:
# (9689, 32)

# %%
tv.head()
# Out:
#        Cobra Kai          Lupin   12 Monkeys          Sherlock  \
# 0           Lost      Jack Ryan    The Flash   Game of thrones
# 1  Sex Education      Dr. House      Kingdom  The Walking Dead
# 2          Ozark  Sex Education  Constantine          Preacher
# 3         Naruto            NaN          NaN               NaN
# 4  Sex Education            NaN          NaN               NaN
#
#        Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7     Unnamed: 8  \
# 0  House of Cards  12 Monkeys    Vikings     Fringe  The Mentalist
# 1             NaN         NaN        NaN        NaN            NaN
# 2         Vikings    The Tick        NaN        NaN            NaN
# 3             NaN         NaN        NaN        NaN            NaN
# 4             NaN         NaN        NaN        NaN            NaN
#
#      Unnamed: 9  ... Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# 0  The Alienist  ...         NaN         NaN         NaN         NaN
# ...

# %%
tv.describe()
# Out:
#         Cobra Kai          Lupin     12 Monkeys       Sherlock  \
# count        9689           7556           5946           4666
# unique        156            145            147            145
# top     Daredevil  Sex Education  Sex Education  Sex Education
# freq          811            646            499            310
#
#                 Unnamed: 4   Unnamed: 5   Unnamed: 6 Unnamed: 7   Unnamed: 8  \
# count                 3678         2837         2197       1664         1231
# unique                 142          130          132        133          122
# top     Two and a half men  Outer Banks  Outer Banks    Lucifer  Outer Banks
# freq                   174          149          120         74           60
#
#        Unnamed: 9  ... Unnamed: 22 Unnamed: 23      Unnamed: 24  \
# count         887  ...          14           8                7
# unique        115  ...          13           7                6
# top       Lucifer  ...   Spartacus        Dark  Shadow and Bone
# ...

# %%
tv = pd.read_csv("TV Shows - Association Rule Learning.csv", header=None)

# %%
tv.describe()
# Out:
#                0              1              2              3   \
# count        9690           7557           5947           4667
# unique        156            145            147            145
# top     Daredevil  Sex Education  Sex Education  Sex Education
# freq          811            646            499            310
#
#                         4            5            6        7            8   \
# count                 3678         2837         2197     1664         1231
# unique                 142          130          132      133          122
# top     Two and a half men  Outer Banks  Outer Banks  Lucifer  Outer Banks
# freq                   174          149          120       74           60
#
#              9   ...         22    23               24                  25  \
# count       887  ...         14     8                7                   7
# unique      115  ...         13     7                6                   7
# ...

# %%
records = []
for i in range(0, 9689):
    records.append([str(tv.values[i,j]) for j in range(0, 32)])

# %%
association_rules = apriori(records, min_support=0.0040, min_confidence=0.6, min_lift=2.7, min_length=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 21

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'Sex Education', 'Jack Ryan', 'Berlin Station'}), support=0.004954071627618949, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jack Ryan', 'Berlin Station'}), items_add=frozenset({'Sex Education'}), confidence=0.7164179104477612, lift=2.8023306961357926)])

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: Sex Education -> Jack Ryan
# Support: 0.004954071627618949
# Confidence: 0.7164179104477612
# Lift: 2.8023306961357926
# ...
# Rule: Family Guy -> Ozark
# Support: 0.005573330581071318
# Confidence: 0.6000000000000001
# Lift: 3.0971763452317536
# ...
# Rule: Sex Education -> Jack Ryan
# Support: 0.0048508618020435545
# Confidence: 0.734375
# Lift: 2.872571406943884
# ...
# Rule: Ozark -> Succession
# Support: 0.005779750232222107
# Confidence: 0.6021505376344085
# Lift: 3.108277335716454
# ...
# Rule: Sex Education -> Family Guy
# Support: 0.004438022499741975
# Confidence: 0.7166666666666666
# Lift: 2.8033037276275063
# ...
# Rule: Sex Education -> Jack Ryan
# Support: 0.004025183197440396
# Confidence: 0.75
# Lift: 2.9336899475171583
# ...
# Rule: The Blacklist -> Ozark
# Support: 0.005057281453194344
# Confidence: 0.6125
# Lift: 3.1617008524240813
# ...
# Rule: Sex Education -> The Blacklist
# Support: 0.005779750232222107
# Confidence: 0.7
# Lift: 2.738110617682681
# ...
# Rule: Sex Education -> nan
# ...
